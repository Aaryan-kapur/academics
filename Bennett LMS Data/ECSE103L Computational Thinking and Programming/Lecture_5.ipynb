# %% [markdown]
# ## Loop

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Types of Loop
# ###        while loop
# ###        for loop

# %% [raw]
# ### while loop
#
# #### Syntex
#
# while(condition):
#     statement1
#     statement2
#     .
#     .
# statement outside while loop

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### write a program to print all even numbers from 0 to n. n is given by user.

# %%
x=0
n=int(input("enter last number-"))
while(x<n):
    print(x)
    x=x+2
# Out:
# enter last number-10
# 0
# 2
# 4
# 6
# 8

# %% [markdown]
# ### write a program to take numbers from the user untill he enter 0 as input. then print sum of all entered number.

# %%
sum =0
x=int(input("enter a number to sum to stop enter 0  -"))
while(x!=0):
    sum +=x
    x=int(input("enter a number to sum to stop enter 0  -"))
print(sum)
# Out:
# enter a number to sum to stop enter 0  -1
# enter a number to sum to stop enter 0  -2
# enter a number to sum to stop enter 0  -6
# enter a number to sum to stop enter 0  -3
# enter a number to sum to stop enter 0  -0
# 12

# %% [markdown]
# ### write a program to print all even numbers between n to m. m should be greater than n.

# %%
n=int(input("enter first number-"))
m=int(input("enter last number-"))
n =n + n%2
while(n<m):
    print(n)
    n=n+2

# %% [markdown]
# ### 1.  Write an efficient program to determine sum of N natural numbers where N is given by user.
# example- 1+2+3....N = ?

# %% [raw]
# https://tinyurl.com/yae88fjy

# %% [markdown]
# ### 2. Let one grain of wheat be placed on the first square of a chessboard, two grains on the second square, four grains on the third square, eight grains on the fourth square, and so on untill all square are filled in chessboard. what wiil be the total weight in ton of grains on whole 8×8 chessboard? If 15432 grains in one kg and 907.18 kg in one ton then.
# ![image.png](attachment:image.png)
