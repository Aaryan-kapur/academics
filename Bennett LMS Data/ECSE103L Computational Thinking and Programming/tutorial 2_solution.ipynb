# %% [markdown]
# # Tutorial 2: Operator Precedence

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1 Calculate following expression:
#
#     a. 20 * 10%2 ** 2
#
#     b. (5+5)*2**(2*2)
#
#     c. 10&5|10^10
#
#     d. (20>>3)/8+5%10
#
#     e. 20+5|2>>2**2%3
#
#     f. (3 and 4) ** (0 or 2)

# %%
print(20*10%2**2)
print((5+5)*2**(2*2))
print(10&5|10^10)
print((20>>3)/8+5%10)
print(20+5|2>>2**2%3)
print((3 and 4) ** (0 or 2))
# Out:
# 0
# 160
# 0
# 5.25
# 25
# 16

# %% [markdown]
# ### 2 Make a flowchart to find given number is even or odd. Then write python program for the same.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input('Enter a number'))
if n%2 ==0:
    print('Even')
else:
    print('odd')
# Out:
# Enter a number8
# Even

# %% [markdown]
# ### 3. Number conversion
#
# a. (32)10 = (?)2 # decimal to binary
#
#     Sol: 100000
#
# b. (32)10 = (?)8 #decimal to octal
#
#     Sol: 40
#
# c. (45)10 = (?)16 # decimal to hexadecimal
#
#     Sol: 2d
#
# d. (1010)2 = (?)10 #binary to decimal
#
#     Sol: 10
#
# e. (24)8 = (?)10 #octal to decimal
#
#     Sol: 20
#
# f. (12A)16 = (?)10 #Hexadecimal to decimal
#
#     Sol: 298

# %% [markdown]
# ### 4 Write python code for to solve question 3.

# %%
print('(32) base 10 = ',format(32,'b'),'base 2')
print('(32) base 10 = ',format(32,'o'),'base 8')
print('(45) base 10 = ',format(45,'x'),'base 16')
print('(1010) base 2 = ',int('1010', 2),'base 10')
print('(24) base 8 = ', int('24', 8),'base 10')
print('(12A) base 16=',  int('12A', 16),'base 10')
# Out:
# (32) base 10 =  100000 base 2
# (32) base 10 =  40 base 8
# (45) base 10 =  2d base 16
# (1010) base 2 =  10 base 10
# (24) base 8 =  20 base 10
# (12A) base 16= 298 base 10

# %% [markdown]
# ### 5 Make a flow chart for following:
#
# First asks the user to enter a number between 1 and 10. Verify that the number is between 1 to 10. Print an error message if not so. Once verified, print the cube of the number if it is odd, or multiply it by 5 if it is even.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6 Write a python program for question 5.

# %%
n=int(input('Enter a number '))
if (n>=1 and n<=10):
    if n%2 ==0:
        print(n*5)
    else:
        print(n**3)
else:
    print('Error')
# Out:
# Enter a number 5
# 125
